# %%
# !unzip  '/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data' /content/drive/MyDrive/Arabic_FakeNews/Model/Corpora/wanlp2020_arabic_fake_news_detection-main.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data, /content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data.zip or /content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data.ZIP.

# %%
# !gunzip /content/drive/MyDrive/Arabic_FakeNews/Model/Corpora/wanlp2020_arabic_fake_news_detection-main/ArNews_dev_GW_order_0.tar.gz
# !gunzip /content/drive/MyDrive/Arabic_FakeNews/Model/Corpora/wanlp2020_arabic_fake_news_detection-main/ArNews_test_GW_order_0.tar.gz
# !gunzip /content/drive/MyDrive/Arabic_FakeNews/Model/Corpora/wanlp2020_arabic_fake_news_detection-main/ArNews_train_GW_order_0.tar.gz

# %%
import tarfile
my_tar = tarfile.open('/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/ArNews_dev_GW_order_0.tar.gz')
my_tar.extractall('/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/') # specify which folder to extract to
my_tar.close()

# %%
import tarfile
my_tar = tarfile.open('/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/ArNews_train_GW_order_0.tar.gz')
my_tar.extractall('/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/') # specify which folder to extract to
my_tar.close()

# %%
import tarfile
my_tar = tarfile.open('/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/ArNews_test_GW_order_0.tar.gz')
my_tar.extractall('/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/') # specify which folder to extract to
my_tar.close()

# %%
import pandas as pd

train_df= pd.read_csv("/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/ArNews_train_GW_order_0.tsv",index_col=0)
train_df.Sentence=train_df.Sentence.astype(str)

train_df.head(5)
# Out:
#         SentID                                           Sentence    label
# 0   S16392_G21  "8 مليون سهم في 888 صفقة , وجري فيها تداول اسه...  Machine
# 1  S12441_G132  "وافاد بلاغ للمديرية الجهوية لمكتب السلامة الص...  Machine
# 2   S31256_G26  "وبالرغم من تسجيل ايجابية تحريك بعض المتابعات ...  Machine
# 3    S11878_G0  "يقول انه كون ثروة بفضل "" البيترو دولار "" و ...  Orginal
# 4   S19534_G11  "وجاء رد الاوربيين سريعا وقاطعا , فاصدرت برلين...  Machine

# %%
d.label.value_counts()
# Out:
# Orginal    49235
# Machine    48665
# Name: label, dtype: int64

# %%
dev_df= pd.read_csv("/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/ArNews_dev_GW_order_0.tsv",index_col=0)
dev_df.head()
# Out:
#        SentID                                           Sentence    label
# 0    S2358_G0  "وطالب مسير المحطة شركة نفطال بمضاعفة التوزيع ...  Orginal
# 1    S294_G40  "حيث قال السانتور في مداخلة له علي هامش مناقشة...  Machine
# 2    S5785_G1  "واطلق عبد نجيب العنان لخياله وافكاره فراح ينت...  Machine
# 3   S6529_G31  " وعن السؤال ذاته يجيب سعيدي بالقول  الحركة تع...  Machine
# 4  S5956_G273  "الجزائريون كانوا يتوقفون في القدس لم يكن الحج...  Machine

# %%
dev_df.label.value_counts()
# Out:
# Orginal    6716
# Machine    6682
# Name: label, dtype: int64

# %%
test_df= pd.read_csv("/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/wanlp2020_arabic_fake_news_detection-main/ArNews_test_GW_order_0.tsv",index_col=0)
test_df.head()
# Out:
#      SentID                                           Sentence    label
# 0  S4566_G0  "قال قائد عسكري فلسطيني متقاعد ان الهجمات الاس...  Orginal
# 1  S533_G25  "المغرب يعلن  الطوارئ الصحية  اعلنت السلطات ال...  Machine
# 2   S513_G0  "وذكر الحساب , ان السلطات السعودية مددت اعتقال...  Orginal
# 3  S5787_G0  "                     ,                            Orginal
# 4  S169_G38  "فالشيء البارز الان هنا في لندن هو الاهتمام ال...  Machine

# %%
dev_df.label.value_counts()
# Out:
# Orginal    6716
# Machine    6682
# Name: label, dtype: int64

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')

def get_VOCAB(corpus):
   # Getting Tokenize the news text
    corpus = corpus.apply(tokenizer.tokenize)

    # news information
    all_words = [word for tokens in corpus for word in tokens]
    sentence_lengths = [len(tokens) for tokens in corpus]

    VOCAB = sorted(list(set(all_words)))
    print("Data with StopWord :")
    print("- words total =", len(all_words))
    print("- vocabulary size =" , len(VOCAB))
    print("- Max sentence length =", max(sentence_lengths))
    print("- Min sentence length =", min(sentence_lengths))    

    return all_words, sentence_lengths,VOCAB

# %%
all_words, sentence_lengths,VOCAB = get_VOCAB(train_df["Sentence"])
# Out:
# Data with StopWord :
# - words total = 5335440
# - vocabulary size = 120275
# - Max sentence length = 977
# - Min sentence length = 0

# %%
total_lens = 0
for sent in train_df["Sentence"]:
    total_lens+=len(sent.split())

print(total_lens/len(train_df["Sentence"]))
# Out:
# 61.44349336057201
