# %% [markdown]
# https://colab.research.google.com/drive/1P9iQHtUH5KUbTVtp8B4-AopZzEEPE0lw?usp=sharing#scrollTo=4YS7XI2bZTyz
#
# https://github.com/aub-mind/arabert

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip -q install transformers==4.2.1
# Out:
#      |████████████████████████████████| 1.8 MB 4.2 MB/s
#      |████████████████████████████████| 895 kB 53.1 MB/s
#      |████████████████████████████████| 2.9 MB 23.4 MB/s

# %%
#Import pipeline
from transformers import pipeline
from transformers import AutoTokenizer,AutoModelForSequenceClassification
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix, precision_score , recall_score

import torch
import pandas as pd

# %%
#Import pipeline
from transformers import pipeline
Model="/content/drive/MyDrive/Arabic_FakeNews/Model/Balance/SavedModels/QaRiB"

tokenizer = AutoTokenizer.from_pretrained(Model)     
model = AutoModelForSequenceClassification.from_pretrained(Model)

# %%
ANS_df=pd.read_csv('/content/drive/MyDrive/Arabic_FakeNews/Model/AraNews/Data/PPV2dev_news.csv')
ANS_df.text=ANS_df.text.astype(str)

# %%
ANS_df
# Out:
#                                                     text  label
# 0      " 8 مليون سهم في 888 صفقة , وجري فيها تداول اس...      1
# 1      " وافاد بلاغ للمديرية الجهوية لمكتب السلامة ال...      0
# 2      " وبالرغم من تسجيل ايجابية تحريك بعض المتابعات...      0
# 3      " يقول انه كون ثروة بفضل " " البيترو دولار " "...      0
# 4      " وجاء رد الاوربيين سريعا وقاطعا , فاصدرت برلي...      0
# ...                                                  ...    ...
# 13393  " لا يمكننا ان نستبعد احتمال ارتفاع قيمة اليوا...      0
# 13394  " ل " " وركب بجانبها , وانطلقا معا الي منزل وا...      0
# 13395  " قصور تشريعي اكد عثمان ابو الوفاء الادريسي , ...      0
# 13396  " في حين بلغ عدد الملفات المتبقية الي غاية متم...      1
# 13397  " من جهته , اعتبر يوسف مزوز , الكاتب العام للم...      0
#
# [13398 rows x 2 columns]

# %%
text=ANS_df.text

# %%
text
# Out:
# 0        " 8 مليون سهم في 888 صفقة , وجري فيها تداول اس...
# 1        " وافاد بلاغ للمديرية الجهوية لمكتب السلامة ال...
# 2        " وبالرغم من تسجيل ايجابية تحريك بعض المتابعات...
# 3        " يقول انه كون ثروة بفضل " " البيترو دولار " "...
# 4        " وجاء رد الاوربيين سريعا وقاطعا , فاصدرت برلي...
#                                ...
# 13393    " لا يمكننا ان نستبعد احتمال ارتفاع قيمة اليوا...
# 13394    " ل " " وركب بجانبها , وانطلقا معا الي منزل وا...
# 13395    " قصور تشريعي اكد عثمان ابو الوفاء الادريسي , ...
# 13396    " في حين بلغ عدد الملفات المتبقية الي غاية متم...
# 13397    " من جهته , اعتبر يوسف مزوز , الكاتب العام للم...
# Name: text, Length: 13398, dtype: object

# %%
y_pred_news = []
for news in ANS_df.text:
  paraphrase = tokenizer(news, return_tensors="pt",max_length=414,truncation=True)
  paraphrase_classification_logits=model(**paraphrase).logits
  paraphrase_results = torch.softmax(paraphrase_classification_logits, dim=1).tolist()[0]

  if(paraphrase_results[0]> paraphrase_results[1]):
    y_pred_news.append(0)
  else:
    y_pred_news.append(1)

# %%
y_test=ANS_df.label
print("Accuracy", accuracy_score(y_test, y_pred_news))
print("\nConfusion matrix\n",confusion_matrix(y_test, y_pred_news))
print("\nClassification report\n",classification_report(y_test, y_pred_news))
print("\n f1_score report ",f1_score(y_test, y_pred_news,average='macro'))
print("\n macro_precision  ",precision_score(y_test, y_pred_news,average='macro'))
print("\n macro_recall  ",recall_score(y_test, y_pred_news,average='macro'))
# Out:
# Accuracy 0.5007463800567249
#
# Confusion matrix
#  [[2336 4346]
#  [2343 4373]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.50      0.35      0.41      6682
#            1       0.50      0.65      0.57      6716
#
#     accuracy                           0.50     13398
#    macro avg       0.50      0.50      0.49     13398
# weighted avg       0.50      0.50      0.49     13398
#
#
#  f1_score report  0.4889328392214205
#
#  macro_precision   0.5004001598089979
#
#  macro_recall   0.5003637776651522

# %% [markdown]
# <!-- Accuracy 0.5452538631346578
#
# Confusion matrix
#  [[437 179]
#  [233  57]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.65      0.71      0.68       616
#            1       0.24      0.20      0.22       290
#
#     accuracy                           0.55       906
#    macro avg       0.45      0.45      0.45       906
# weighted avg       0.52      0.55      0.53       906
#
#
#  f1_score report
#  0.44817839381700564 -->
